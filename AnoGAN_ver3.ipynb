# %%
'''Googleドライブマウント'''

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ライブラリのインポート
import random
import math
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms
import torchvision.utils as vutils

import os

# ランダムシード
torch.manual_seed(1234)
np.random.seed(1234)
random.seed(1234)

# %%
'''MNISTデータセットをダウンロード'''

from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', version=1, data_home="./data/", as_frame=False) 

# データの取り出し
X = mnist.data
y = mnist.target

# フォルダ「data」の下にフォルダ「img_78」を作成する
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1
        
    # 7と8を200枚ずつ作成したらbreak
    if (count7>=max_num) and (count8>=max_num):
        break

# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)

# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=20  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count2+=1
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # 64×64に拡大
        pil_img_f.save(file_path)  # 保存
        count8+=1

# フォルダ「data」の下にフォルダ「img_78_28size」を作成する
data_dir_path = "./data/img_78_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# MNISTから数字7、8の画像だけフォルダ「img_78_28size」に画像として保存していく
count7=0
count8=0
max_num=200  # 画像は200枚ずつ作成する

for i in range(len(X)):
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/img_78_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/img_78_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
    
    if (count7>=max_num) and (count8>=max_num):
        break

# フォルダ「data」の下にフォルダ「test」を作成する
data_dir_path = "./data/test_28size/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# 上記で7,8の画像を作成するのに使用したindexの最終値
i_start = i+1
print(i_start)

# MNISTから数字7、8の画像だけフォルダ「img_78」に画像として保存していく
count2=0
count7=0
count8=0
max_num=20  # 画像は5枚ずつ作成する

for i in range(i_start,len(X)):  # i_startから始める
    
    # 画像2の作成
    if (y[i] is "2") and (count2<max_num):
        file_path="./data/test_28size/img_2_"+str(count2)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count2+=1 
    
    # 画像7の作成
    if (y[i] is "7") and (count7<max_num):
        file_path="./data/test_28size/img_7_"+str(count7)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28×28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count7+=1 
    
    # 画像8の作成
    if (y[i] is "8") and (count8<max_num):
        file_path="./data/test_28size/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # 画像を28*28の形に変形
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # 画像をPILに
        pil_img_f.save(file_path)  # 保存
        count8+=1
# Out:
# 2244
# 2244

# %%
'''デバイスの設定'''

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
'''初期設定'''

dir_path = "/content/drive/My Drive/Colab Notebooks/AnoGAN/result"
os.makedirs(dir_path, exist_ok=True)

model_name = "AnoGAN"
f_path_result = f"/content/drive/My Drive/Colab Notebooks/AnoGAN/result/{model_name}"
f_path_params = f"/content/drive/My Drive/Colab Notebooks/AnoGAN/params/{model_name}"

os.makedirs(f_path_result, exist_ok=True)
os.makedirs(f_path_params, exist_ok=True)

image_size = 64

# %%
'''ハイパーパラメータの設定'''

import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--num_epochs", type=int, default=300)
parser.add_argument("--batch_size", type=int, default=64)
parser.add_argument("--lr_g", type=float, default=1e-4)
parser.add_argument("--lr_d", type=float, default=4e-4)
parser.add_argument("--nch_g", type=int, default=128) # 生成器のチャネル数
parser.add_argument("--nch_d", type=int, default=128) # 識別器のチャネル数
parser.add_argument("--z_dim", type=int, default=20) # ノイズの次元
parser.add_argument("--beta1", type=float, default=0.0) # Adamのハイパーパラメータ
parser.add_argument("--beta2", type=float, default=0.9) # Adamのハイパーパラメータ
opt = parser.parse_args(args=[])
print(opt)
# Out:
# Namespace(batch_size=64, beta1=0.0, beta2=0.9, lr_d=0.0004, lr_g=0.0001, nch_d=128, nch_g=128, num_epochs=300, z_dim=20)

# %%
'''生成器の実装'''

class Generator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.ConvTranspose2d(z_dim, image_size * 8,
                               kernel_size=4, stride=1),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        self.layer2 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 8, image_size * 4,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 4),
            nn.ReLU(inplace=True))

        self.layer3 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 4, image_size * 2,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size * 2),
            nn.ReLU(inplace=True))

        self.layer4 = nn.Sequential(
            nn.ConvTranspose2d(image_size * 2, image_size,
                               kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())
        # 白黒画像なので出力チャネルは1つだけ

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.last(out)

        return out

# %%
# 動作確認
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# 入力する乱数
input_z = torch.randn(1, 20)

# テンソルサイズを(1, 20, 1, 1)に変形
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# 偽画像を出力
fake_images = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, 'gray')
plt.show()

# %%
'''識別器の実装'''

class Discriminator(nn.Module):

    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()

        self.layer1 = nn.Sequential(
            nn.Conv2d(1, image_size, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))
        # 白黒画像なので入力チャネルは1つだけ

        self.layer2 = nn.Sequential(
            nn.Conv2d(image_size, image_size*2, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer3 = nn.Sequential(
            nn.Conv2d(image_size*2, image_size*4, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.layer4 = nn.Sequential(
            nn.Conv2d(image_size*4, image_size*8, kernel_size=4,
                      stride=2, padding=1),
            nn.LeakyReLU(0.1, inplace=True))

        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)

        feature = out  # 最後にチャネルを1つに集約する手前の情報
        feature = feature.view(feature.size()[0], -1)  # 2次元に変換

        out = self.last(out)

        return out, feature

# %%
# 動作確認
D = Discriminator(z_dim=20, image_size=64)

# 偽画像を生成
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images = G(input_z)

# 偽画像をDに入力
d_out = D(fake_images)

# 出力d_outにSigmoidをかけて0から1に変換
print(nn.Sigmoid()(d_out[0]))

# feature
print(d_out[1].shape)
# Out:
# tensor([[[[0.5066]]]], grad_fn=<SigmoidBackward0>)
# torch.Size([1, 8192])

# %%
def make_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(200):
        img_path = "./data/img_78/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/img_78/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


class ImageTransform():
    """画像の前処理クラス"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)


class GAN_Img_Dataset(data.Dataset):
    """画像のDatasetクラス。PyTorchのDatasetクラスを継承"""

    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        '''画像の枚数を返す'''
        return len(self.file_list)

    def __getitem__(self, index):
        '''前処理をした画像のTensor形式のデータを取得'''

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # 画像の前処理
        img_transformed = self.transform(img)

        return img_transformed


# DataLoaderの作成と動作確認

# ファイルリストを作成
train_img_list=make_datapath_list()

# Datasetを作成
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list=train_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# 動作の確認
batch_iterator = iter(train_dataloader)  # イテレータに変換
imgs = next(batch_iterator)  # 1番目の要素を取り出す
print(imgs.size())  # torch.Size([64, 1, 64, 64])
# Out:
# torch.Size([64, 1, 64, 64])

# %%
# ネットワークの初期化
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Conv2dとConvTranspose2dの初期化
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # BatchNorm2dの初期化
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)


# 初期化の実施
G.apply(weights_init)
D.apply(weights_init)

print("ネットワークの初期化完了")
# Out:
# ネットワークの初期化完了

# %%
'''損失関数と最適化関数の定義'''

# 誤差関数を定義
criterion = nn.BCEWithLogitsLoss(reduction='mean')

# 最適化手法の設定
optimizerG = torch.optim.Adam(G.parameters(), opt.lr_g, [opt.beta1, opt.beta2])
optimizerD = torch.optim.Adam(D.parameters(), opt.lr_d, [opt.beta1, opt.beta2])

# %%
'''パラメータを保存する関数の定義'''

def save_params(file_path, epoch, netD, netG):
    torch.save(
        netG.state_dict(),
        file_path + "/g_{:04d}.pth".format(epoch)
    )

    torch.save(
        netD.state_dict(),
        file_path + "/d_{:04d}.pth".format(epoch)
    )

# %%
# モデルを学習させる関数を作成

lossesD = []
lossesG = []
raw_lossesD = []
raw_lossesG = []

def train_model(G, D, dataloader, num_epochs):

    # パラメータをハードコーディング
    mini_batch_size = opt.batch_size

    # ネットワークをGPUへ
    G.to(device)
    D.to(device)

    G.train()  # モデルを訓練モードに
    D.train()  # モデルを訓練モードに

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True

    # 画像の枚数
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # イテレーションカウンタをセット
    iteration = 1

    # epochのループ
    for epoch in range(num_epochs):

        # 開始時刻を保存
        t_epoch_start = time.time()
        epoch_g_loss = 0.0  # epochの損失和
        epoch_d_loss = 0.0  # epochの損失和

        # データローダーからminibatchずつ取り出すループ
        for imgs in dataloader:

            # --------------------
            # 1. Discriminatorの学習
            # --------------------
            # ミニバッチがサイズが1だと、バッチノーマライゼーションでエラーになるのでさける
            if imgs.size()[0] == 1:
                continue

            # GPUが使えるならGPUにデータを送る
            imgs = imgs.to(device)

            # 正解ラベルと偽ラベルを作成
            # epochの最後のイテレーションはミニバッチの数が少なくなる
            mini_batch_size = imgs.size()[0]
            label_real = torch.full((mini_batch_size,), 1).to(device)
            label_fake = torch.full((mini_batch_size,), 0).to(device)

            # 真の画像を判定
            d_out_real, _ = D(imgs)

            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, opt.z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 誤差を計算
            label_real = label_real.type_as(d_out_real.view(-1))
            d_loss_real = criterion(d_out_real.view(-1), label_real)
            label_fake = label_fake.type_as(d_out_fake.view(-1))
            d_loss_fake = criterion(d_out_fake.view(-1), label_fake)
            d_loss = d_loss_real + d_loss_fake

            # バックプロパゲーション
            optimizerG.zero_grad()
            optimizerD.zero_grad()

            d_loss.backward()
            optimizerD.step()

            # --------------------
            # 2. Generatorの学習
            # --------------------
            # 偽の画像を生成して判定
            input_z = torch.randn(mini_batch_size, opt.z_dim).to(device)
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            fake_images = G(input_z)
            d_out_fake, _ = D(fake_images)

            # 誤差を計算
            g_loss = criterion(d_out_fake.view(-1), label_real)

            # バックプロパゲーション
            optimizerG.zero_grad()
            optimizerD.zero_grad()
            g_loss.backward()
            optimizerG.step()

            # --------------------
            # 3. 記録
            # --------------------
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            raw_lossesD.append(epoch_d_loss)
            raw_lossesG.append(epoch_g_loss)
            iteration += 1

        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('-------------')
        print('epoch {} || Epoch_D_Loss:{:.4f} ||Epoch_G_Loss:{:.4f}'.format(
            epoch+1, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        lossesD.append(epoch_d_loss/batch_size)
        lossesG.append(epoch_g_loss/batch_size)
        
        # パラメータ、画像を保存しない場合はコメントアウトする
        # vutils.save_image(fake_images, f_path_result + f"/{epoch+1}.jpg")
        # save_params(f_path_params, epoch, D, G)

    print("総イテレーション回数:", iteration)

    return G, D

# %%
# 学習・検証を実行する
G_update, D_update = train_model(G, D, dataloader=train_dataloader, num_epochs=opt.num_epochs)
# Out:
# -------------
# epoch 1 || Epoch_D_Loss:0.1048 ||Epoch_G_Loss:0.1636
# timer:  2.4162 sec.
# -------------
# epoch 2 || Epoch_D_Loss:0.0507 ||Epoch_G_Loss:0.2014
# timer:  1.7436 sec.
# -------------
# epoch 3 || Epoch_D_Loss:0.0304 ||Epoch_G_Loss:0.3949
# timer:  1.7364 sec.
# -------------
# epoch 4 || Epoch_D_Loss:0.1417 ||Epoch_G_Loss:0.0999
# timer:  1.7385 sec.
# -------------
# epoch 5 || Epoch_D_Loss:0.0156 ||Epoch_G_Loss:0.3069
# timer:  1.7473 sec.
# -------------
# epoch 6 || Epoch_D_Loss:0.2455 ||Epoch_G_Loss:0.2533
# timer:  1.7538 sec.
# -------------
# epoch 7 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.1095
# timer:  1.7464 sec.
# -------------
# epoch 8 || Epoch_D_Loss:0.0210 ||Epoch_G_Loss:0.2657
# timer:  1.7538 sec.
# -------------
# epoch 9 || Epoch_D_Loss:0.0043 ||Epoch_G_Loss:0.4129
# timer:  1.7574 sec.
# -------------
# epoch 10 || Epoch_D_Loss:0.0596 ||Epoch_G_Loss:0.3880
# timer:  1.7588 sec.
# -------------
# epoch 11 || Epoch_D_Loss:0.0558 ||Epoch_G_Loss:0.5040
# timer:  1.7472 sec.
# -------------
# epoch 12 || Epoch_D_Loss:0.1564 ||Epoch_G_Loss:0.2596
# timer:  1.7458 sec.
# -------------
# epoch 13 || Epoch_D_Loss:0.0050 ||Epoch_G_Loss:0.4537
# timer:  1.7577 sec.
# -------------
# epoch 14 || Epoch_D_Loss:0.1991 ||Epoch_G_Loss:0.4316
# timer:  1.7434 sec.
# -------------
# epoch 15 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.4279
# timer:  1.7588 sec.
# -------------
# epoch 16 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.5300
# timer:  1.7552 sec.
# -------------
# epoch 17 || Epoch_D_Loss:0.2228 ||Epoch_G_Loss:0.3832
# timer:  1.7654 sec.
# -------------
# epoch 18 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.2727
# timer:  1.7518 sec.
# -------------
# epoch 19 || Epoch_D_Loss:0.1344 ||Epoch_G_Loss:0.3700
# timer:  1.7520 sec.
# -------------
# epoch 20 || Epoch_D_Loss:0.0230 ||Epoch_G_Loss:0.2781
# timer:  1.7552 sec.
# -------------
# epoch 21 || Epoch_D_Loss:0.1802 ||Epoch_G_Loss:0.2870
# timer:  1.7401 sec.
# -------------
# epoch 22 || Epoch_D_Loss:0.0368 ||Epoch_G_Loss:0.2541
# timer:  1.7530 sec.
# -------------
# epoch 23 || Epoch_D_Loss:0.1055 ||Epoch_G_Loss:0.2780
# timer:  1.7477 sec.
# -------------
# epoch 24 || Epoch_D_Loss:0.0979 ||Epoch_G_Loss:0.2415
# timer:  1.7546 sec.
# -------------
# epoch 25 || Epoch_D_Loss:0.1018 ||Epoch_G_Loss:0.2175
# timer:  1.7359 sec.
# -------------
# epoch 26 || Epoch_D_Loss:0.0233 ||Epoch_G_Loss:0.3064
# timer:  1.7372 sec.
# -------------
# epoch 27 || Epoch_D_Loss:0.0888 ||Epoch_G_Loss:0.2681
# timer:  1.7430 sec.
# -------------
# epoch 28 || Epoch_D_Loss:0.1561 ||Epoch_G_Loss:0.2376
# timer:  1.7612 sec.
# -------------
# epoch 29 || Epoch_D_Loss:0.1425 ||Epoch_G_Loss:0.1757
# timer:  1.8662 sec.
# -------------
# epoch 30 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.1630
# timer:  1.9772 sec.
# -------------
# epoch 31 || Epoch_D_Loss:0.1361 ||Epoch_G_Loss:0.1625
# timer:  1.8365 sec.
# -------------
# epoch 32 || Epoch_D_Loss:0.0988 ||Epoch_G_Loss:0.1924
# timer:  1.7335 sec.
# -------------
# epoch 33 || Epoch_D_Loss:0.1674 ||Epoch_G_Loss:0.2654
# timer:  1.7388 sec.
# -------------
# epoch 34 || Epoch_D_Loss:0.1049 ||Epoch_G_Loss:0.1667
# timer:  1.7277 sec.
# -------------
# epoch 35 || Epoch_D_Loss:0.0989 ||Epoch_G_Loss:0.1674
# timer:  1.7314 sec.
# -------------
# epoch 36 || Epoch_D_Loss:0.0916 ||Epoch_G_Loss:0.2475
# timer:  1.7332 sec.
# -------------
# epoch 37 || Epoch_D_Loss:0.1254 ||Epoch_G_Loss:0.1441
# timer:  1.7292 sec.
# -------------
# epoch 38 || Epoch_D_Loss:0.1214 ||Epoch_G_Loss:0.1858
# timer:  1.7455 sec.
# -------------
# epoch 39 || Epoch_D_Loss:0.0905 ||Epoch_G_Loss:0.1985
# timer:  1.7469 sec.
# -------------
# epoch 40 || Epoch_D_Loss:0.1268 ||Epoch_G_Loss:0.1405
# timer:  1.7415 sec.
# -------------
# epoch 41 || Epoch_D_Loss:0.1246 ||Epoch_G_Loss:0.1737
# timer:  1.7378 sec.
# -------------
# epoch 42 || Epoch_D_Loss:0.1100 ||Epoch_G_Loss:0.1499
# timer:  1.7374 sec.
# -------------
# epoch 43 || Epoch_D_Loss:0.1086 ||Epoch_G_Loss:0.1673
# timer:  1.7461 sec.
# -------------
# epoch 44 || Epoch_D_Loss:0.1017 ||Epoch_G_Loss:0.1791
# timer:  1.7441 sec.
# -------------
# epoch 45 || Epoch_D_Loss:0.1250 ||Epoch_G_Loss:0.2003
# timer:  1.7457 sec.
# -------------
# epoch 46 || Epoch_D_Loss:0.0954 ||Epoch_G_Loss:0.1553
# timer:  1.7320 sec.
# -------------
# epoch 47 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.1425
# timer:  1.7375 sec.
# -------------
# epoch 48 || Epoch_D_Loss:0.1232 ||Epoch_G_Loss:0.1654
# timer:  1.7466 sec.
# -------------
# epoch 49 || Epoch_D_Loss:0.1101 ||Epoch_G_Loss:0.1522
# timer:  1.7613 sec.
# -------------
# epoch 50 || Epoch_D_Loss:0.1125 ||Epoch_G_Loss:0.1457
# timer:  1.7443 sec.
# -------------
# epoch 51 || Epoch_D_Loss:0.1219 ||Epoch_G_Loss:0.1439
# timer:  1.7383 sec.
# -------------
# epoch 52 || Epoch_D_Loss:0.1146 ||Epoch_G_Loss:0.1469
# timer:  1.7339 sec.
# -------------
# epoch 53 || Epoch_D_Loss:0.1137 ||Epoch_G_Loss:0.1310
# timer:  1.7349 sec.
# -------------
# epoch 54 || Epoch_D_Loss:0.1178 ||Epoch_G_Loss:0.1290
# timer:  1.7295 sec.
# -------------
# epoch 55 || Epoch_D_Loss:0.1211 ||Epoch_G_Loss:0.1362
# timer:  1.7237 sec.
# -------------
# epoch 56 || Epoch_D_Loss:0.1227 ||Epoch_G_Loss:0.1493
# timer:  1.7303 sec.
# -------------
# epoch 57 || Epoch_D_Loss:0.1004 ||Epoch_G_Loss:0.1282
# timer:  1.7369 sec.
# -------------
# epoch 58 || Epoch_D_Loss:0.1114 ||Epoch_G_Loss:0.1517
# timer:  1.7364 sec.
# -------------
# epoch 59 || Epoch_D_Loss:0.1009 ||Epoch_G_Loss:0.1648
# timer:  1.7438 sec.
# -------------
# epoch 60 || Epoch_D_Loss:0.0951 ||Epoch_G_Loss:0.1568
# timer:  1.7299 sec.
# -------------
# epoch 61 || Epoch_D_Loss:0.1025 ||Epoch_G_Loss:0.1846
# timer:  1.7265 sec.
# -------------
# epoch 62 || Epoch_D_Loss:0.1034 ||Epoch_G_Loss:0.1609
# timer:  1.7527 sec.
# -------------
# epoch 63 || Epoch_D_Loss:0.0997 ||Epoch_G_Loss:0.1555
# timer:  1.7468 sec.
# -------------
# epoch 64 || Epoch_D_Loss:0.0933 ||Epoch_G_Loss:0.1797
# timer:  1.7487 sec.
# -------------
# epoch 65 || Epoch_D_Loss:0.0940 ||Epoch_G_Loss:0.1947
# timer:  1.7380 sec.
# -------------
# epoch 66 || Epoch_D_Loss:0.0802 ||Epoch_G_Loss:0.1696
# timer:  1.7508 sec.
# -------------
# epoch 67 || Epoch_D_Loss:0.0894 ||Epoch_G_Loss:0.1926
# timer:  1.7452 sec.
# -------------
# epoch 68 || Epoch_D_Loss:0.0812 ||Epoch_G_Loss:0.1896
# timer:  1.7378 sec.
# -------------
# epoch 69 || Epoch_D_Loss:0.0983 ||Epoch_G_Loss:0.1791
# timer:  1.7356 sec.
# -------------
# epoch 70 || Epoch_D_Loss:0.0739 ||Epoch_G_Loss:0.1939
# timer:  1.7354 sec.
# -------------
# epoch 71 || Epoch_D_Loss:0.1028 ||Epoch_G_Loss:0.1910
# timer:  1.7336 sec.
# -------------
# epoch 72 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.1783
# timer:  1.7265 sec.
# -------------
# epoch 73 || Epoch_D_Loss:0.0761 ||Epoch_G_Loss:0.2210
# timer:  1.7248 sec.
# -------------
# epoch 74 || Epoch_D_Loss:0.0851 ||Epoch_G_Loss:0.1826
# timer:  1.7189 sec.
# -------------
# epoch 75 || Epoch_D_Loss:0.0908 ||Epoch_G_Loss:0.2054
# timer:  1.7317 sec.
# -------------
# epoch 76 || Epoch_D_Loss:0.0824 ||Epoch_G_Loss:0.2139
# timer:  1.7325 sec.
# -------------
# epoch 77 || Epoch_D_Loss:0.0867 ||Epoch_G_Loss:0.2163
# timer:  1.7263 sec.
# -------------
# epoch 78 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2021
# timer:  1.7423 sec.
# -------------
# epoch 79 || Epoch_D_Loss:0.0895 ||Epoch_G_Loss:0.2319
# timer:  1.7486 sec.
# -------------
# epoch 80 || Epoch_D_Loss:0.0726 ||Epoch_G_Loss:0.1934
# timer:  1.7268 sec.
# -------------
# epoch 81 || Epoch_D_Loss:0.0781 ||Epoch_G_Loss:0.2241
# timer:  1.7364 sec.
# -------------
# epoch 82 || Epoch_D_Loss:0.0929 ||Epoch_G_Loss:0.2078
# timer:  1.7348 sec.
# -------------
# epoch 83 || Epoch_D_Loss:0.0861 ||Epoch_G_Loss:0.1960
# timer:  1.7398 sec.
# -------------
# epoch 84 || Epoch_D_Loss:0.0805 ||Epoch_G_Loss:0.2115
# timer:  1.7327 sec.
# -------------
# epoch 85 || Epoch_D_Loss:0.0738 ||Epoch_G_Loss:0.2262
# timer:  1.7361 sec.
# -------------
# epoch 86 || Epoch_D_Loss:0.0811 ||Epoch_G_Loss:0.2069
# timer:  1.7279 sec.
# -------------
# epoch 87 || Epoch_D_Loss:0.0930 ||Epoch_G_Loss:0.1902
# timer:  1.7497 sec.
# -------------
# epoch 88 || Epoch_D_Loss:0.0760 ||Epoch_G_Loss:0.2183
# timer:  1.7435 sec.
# -------------
# epoch 89 || Epoch_D_Loss:0.0763 ||Epoch_G_Loss:0.1988
# timer:  1.7253 sec.
# -------------
# epoch 90 || Epoch_D_Loss:0.0918 ||Epoch_G_Loss:0.2063
# timer:  1.7259 sec.
# -------------
# epoch 91 || Epoch_D_Loss:0.0710 ||Epoch_G_Loss:0.2169
# timer:  1.7214 sec.
# -------------
# epoch 92 || Epoch_D_Loss:0.0861 ||Epoch_G_Loss:0.2119
# timer:  1.7444 sec.
# -------------
# epoch 93 || Epoch_D_Loss:0.0700 ||Epoch_G_Loss:0.2265
# timer:  1.7336 sec.
# -------------
# epoch 94 || Epoch_D_Loss:0.0863 ||Epoch_G_Loss:0.2255
# timer:  1.7276 sec.
# -------------
# epoch 95 || Epoch_D_Loss:0.0755 ||Epoch_G_Loss:0.2172
# timer:  1.7412 sec.
# -------------
# epoch 96 || Epoch_D_Loss:0.0766 ||Epoch_G_Loss:0.2240
# timer:  1.7343 sec.
# -------------
# epoch 97 || Epoch_D_Loss:0.0858 ||Epoch_G_Loss:0.2336
# timer:  1.7433 sec.
# -------------
# epoch 98 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.2194
# timer:  1.7407 sec.
# -------------
# epoch 99 || Epoch_D_Loss:0.0923 ||Epoch_G_Loss:0.2205
# timer:  1.7488 sec.
# -------------
# epoch 100 || Epoch_D_Loss:0.0801 ||Epoch_G_Loss:0.2015
# timer:  1.7333 sec.
# -------------
# epoch 101 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.2070
# timer:  1.7347 sec.
# -------------
# epoch 102 || Epoch_D_Loss:0.0753 ||Epoch_G_Loss:0.2410
# timer:  1.7304 sec.
# -------------
# epoch 103 || Epoch_D_Loss:0.0748 ||Epoch_G_Loss:0.2170
# timer:  1.7171 sec.
# -------------
# epoch 104 || Epoch_D_Loss:0.0729 ||Epoch_G_Loss:0.2407
# timer:  1.7309 sec.
# -------------
# epoch 105 || Epoch_D_Loss:0.0886 ||Epoch_G_Loss:0.2250
# timer:  1.7234 sec.
# -------------
# epoch 106 || Epoch_D_Loss:0.0733 ||Epoch_G_Loss:0.2190
# timer:  1.7411 sec.
# -------------
# epoch 107 || Epoch_D_Loss:0.0799 ||Epoch_G_Loss:0.2093
# timer:  1.7280 sec.
# -------------
# epoch 108 || Epoch_D_Loss:0.0710 ||Epoch_G_Loss:0.2518
# timer:  1.7401 sec.
# -------------
# epoch 109 || Epoch_D_Loss:0.0740 ||Epoch_G_Loss:0.2091
# timer:  1.7458 sec.
# -------------
# epoch 110 || Epoch_D_Loss:0.0708 ||Epoch_G_Loss:0.2946
# timer:  1.7333 sec.
# -------------
# epoch 111 || Epoch_D_Loss:0.1080 ||Epoch_G_Loss:0.1625
# timer:  1.7283 sec.
# -------------
# epoch 112 || Epoch_D_Loss:0.0770 ||Epoch_G_Loss:0.2341
# timer:  1.7385 sec.
# -------------
# epoch 113 || Epoch_D_Loss:0.0606 ||Epoch_G_Loss:0.2528
# timer:  1.7281 sec.
# -------------
# epoch 114 || Epoch_D_Loss:0.0744 ||Epoch_G_Loss:0.2247
# timer:  1.7351 sec.
# -------------
# epoch 115 || Epoch_D_Loss:0.0710 ||Epoch_G_Loss:0.2664
# timer:  1.7470 sec.
# -------------
# epoch 116 || Epoch_D_Loss:0.0776 ||Epoch_G_Loss:0.2286
# timer:  1.7276 sec.
# -------------
# epoch 117 || Epoch_D_Loss:0.0706 ||Epoch_G_Loss:0.2432
# timer:  1.7395 sec.
# -------------
# epoch 118 || Epoch_D_Loss:0.0769 ||Epoch_G_Loss:0.2258
# timer:  1.7340 sec.
# -------------
# epoch 119 || Epoch_D_Loss:0.0809 ||Epoch_G_Loss:0.2400
# timer:  1.7284 sec.
# -------------
# epoch 120 || Epoch_D_Loss:0.0648 ||Epoch_G_Loss:0.2664
# timer:  1.7367 sec.
# -------------
# epoch 121 || Epoch_D_Loss:0.0874 ||Epoch_G_Loss:0.2113
# timer:  1.7268 sec.
# -------------
# epoch 122 || Epoch_D_Loss:0.0636 ||Epoch_G_Loss:0.2544
# timer:  1.7232 sec.
# -------------
# epoch 123 || Epoch_D_Loss:0.0686 ||Epoch_G_Loss:0.2402
# timer:  1.7330 sec.
# -------------
# epoch 124 || Epoch_D_Loss:0.0767 ||Epoch_G_Loss:0.2563
# timer:  1.7405 sec.
# -------------
# epoch 125 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.2449
# timer:  1.7375 sec.
# -------------
# epoch 126 || Epoch_D_Loss:0.0649 ||Epoch_G_Loss:0.2701
# timer:  1.7376 sec.
# -------------
# epoch 127 || Epoch_D_Loss:0.0658 ||Epoch_G_Loss:0.2861
# timer:  1.7305 sec.
# -------------
# epoch 128 || Epoch_D_Loss:0.0785 ||Epoch_G_Loss:0.2201
# timer:  1.7367 sec.
# -------------
# epoch 129 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.2878
# timer:  1.7415 sec.
# -------------
# epoch 130 || Epoch_D_Loss:0.0555 ||Epoch_G_Loss:0.2589
# timer:  1.7440 sec.
# -------------
# epoch 131 || Epoch_D_Loss:0.0714 ||Epoch_G_Loss:0.2553
# timer:  1.7450 sec.
# -------------
# epoch 132 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.2713
# timer:  1.7314 sec.
# -------------
# epoch 133 || Epoch_D_Loss:0.0669 ||Epoch_G_Loss:0.2695
# timer:  1.7470 sec.
# -------------
# epoch 134 || Epoch_D_Loss:0.0657 ||Epoch_G_Loss:0.2631
# timer:  1.7205 sec.
# -------------
# epoch 135 || Epoch_D_Loss:0.0735 ||Epoch_G_Loss:0.2687
# timer:  1.7287 sec.
# -------------
# epoch 136 || Epoch_D_Loss:0.0443 ||Epoch_G_Loss:0.2866
# timer:  1.7184 sec.
# -------------
# epoch 137 || Epoch_D_Loss:0.0670 ||Epoch_G_Loss:0.2810
# timer:  1.7527 sec.
# -------------
# epoch 138 || Epoch_D_Loss:0.0579 ||Epoch_G_Loss:0.2607
# timer:  1.7375 sec.
# -------------
# epoch 139 || Epoch_D_Loss:0.0540 ||Epoch_G_Loss:0.3370
# timer:  1.7339 sec.
# -------------
# epoch 140 || Epoch_D_Loss:0.0694 ||Epoch_G_Loss:0.2927
# timer:  1.7332 sec.
# -------------
# epoch 141 || Epoch_D_Loss:0.0619 ||Epoch_G_Loss:0.2691
# timer:  1.7355 sec.
# -------------
# epoch 142 || Epoch_D_Loss:0.0645 ||Epoch_G_Loss:0.3169
# timer:  1.7272 sec.
# -------------
# epoch 143 || Epoch_D_Loss:0.0558 ||Epoch_G_Loss:0.2871
# timer:  1.7358 sec.
# -------------
# epoch 144 || Epoch_D_Loss:0.0542 ||Epoch_G_Loss:0.3069
# timer:  1.7401 sec.
# -------------
# epoch 145 || Epoch_D_Loss:0.0466 ||Epoch_G_Loss:0.2999
# timer:  1.7387 sec.
# -------------
# epoch 146 || Epoch_D_Loss:0.0666 ||Epoch_G_Loss:0.2960
# timer:  1.7290 sec.
# -------------
# epoch 147 || Epoch_D_Loss:0.0424 ||Epoch_G_Loss:0.3074
# timer:  1.7506 sec.
# -------------
# epoch 148 || Epoch_D_Loss:0.0693 ||Epoch_G_Loss:0.2819
# timer:  1.7477 sec.
# -------------
# epoch 149 || Epoch_D_Loss:0.0501 ||Epoch_G_Loss:0.3003
# timer:  1.7313 sec.
# -------------
# epoch 150 || Epoch_D_Loss:0.0487 ||Epoch_G_Loss:0.3316
# timer:  1.7319 sec.
# -------------
# epoch 151 || Epoch_D_Loss:0.0502 ||Epoch_G_Loss:0.3180
# timer:  1.7259 sec.
# -------------
# epoch 152 || Epoch_D_Loss:0.0520 ||Epoch_G_Loss:0.3079
# timer:  1.7238 sec.
# -------------
# epoch 153 || Epoch_D_Loss:0.0519 ||Epoch_G_Loss:0.3094
# timer:  1.7288 sec.
# -------------
# epoch 154 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.3742
# timer:  1.7348 sec.
# -------------
# epoch 155 || Epoch_D_Loss:0.0582 ||Epoch_G_Loss:0.2912
# timer:  1.7356 sec.
# -------------
# epoch 156 || Epoch_D_Loss:0.0455 ||Epoch_G_Loss:0.3474
# timer:  1.7287 sec.
# -------------
# epoch 157 || Epoch_D_Loss:0.0497 ||Epoch_G_Loss:0.3075
# timer:  1.7355 sec.
# -------------
# epoch 158 || Epoch_D_Loss:0.0436 ||Epoch_G_Loss:0.3494
# timer:  1.7380 sec.
# -------------
# epoch 159 || Epoch_D_Loss:0.0509 ||Epoch_G_Loss:0.3369
# timer:  1.7350 sec.
# -------------
# epoch 160 || Epoch_D_Loss:0.0296 ||Epoch_G_Loss:0.3853
# timer:  1.7366 sec.
# -------------
# epoch 161 || Epoch_D_Loss:0.0580 ||Epoch_G_Loss:0.3351
# timer:  1.7338 sec.
# -------------
# epoch 162 || Epoch_D_Loss:0.0536 ||Epoch_G_Loss:0.3482
# timer:  1.7428 sec.
# -------------
# epoch 163 || Epoch_D_Loss:0.0488 ||Epoch_G_Loss:0.3456
# timer:  1.7312 sec.
# -------------
# epoch 164 || Epoch_D_Loss:0.0442 ||Epoch_G_Loss:0.2821
# timer:  1.7372 sec.
# -------------
# epoch 165 || Epoch_D_Loss:0.0629 ||Epoch_G_Loss:0.3352
# timer:  1.7273 sec.
# -------------
# epoch 166 || Epoch_D_Loss:0.0489 ||Epoch_G_Loss:0.3568
# timer:  1.7356 sec.
# -------------
# epoch 167 || Epoch_D_Loss:0.0407 ||Epoch_G_Loss:0.3615
# timer:  1.7287 sec.
# -------------
# epoch 168 || Epoch_D_Loss:0.0446 ||Epoch_G_Loss:0.3637
# timer:  1.7497 sec.
# -------------
# epoch 169 || Epoch_D_Loss:0.0435 ||Epoch_G_Loss:0.3758
# timer:  1.7313 sec.
# -------------
# epoch 170 || Epoch_D_Loss:0.0426 ||Epoch_G_Loss:0.3666
# timer:  1.7236 sec.
# -------------
# epoch 171 || Epoch_D_Loss:0.0371 ||Epoch_G_Loss:0.4176
# timer:  1.7491 sec.
# -------------
# epoch 172 || Epoch_D_Loss:0.0520 ||Epoch_G_Loss:0.3076
# timer:  1.7302 sec.
# -------------
# epoch 173 || Epoch_D_Loss:0.0347 ||Epoch_G_Loss:0.3917
# timer:  1.7267 sec.
# -------------
# epoch 174 || Epoch_D_Loss:0.0549 ||Epoch_G_Loss:0.3629
# timer:  1.7323 sec.
# -------------
# epoch 175 || Epoch_D_Loss:0.0329 ||Epoch_G_Loss:0.3756
# timer:  1.7313 sec.
# -------------
# epoch 176 || Epoch_D_Loss:0.0475 ||Epoch_G_Loss:0.3673
# timer:  1.7457 sec.
# -------------
# epoch 177 || Epoch_D_Loss:0.0301 ||Epoch_G_Loss:0.3552
# timer:  1.7495 sec.
# -------------
# epoch 178 || Epoch_D_Loss:0.0426 ||Epoch_G_Loss:0.3990
# timer:  1.7441 sec.
# -------------
# epoch 179 || Epoch_D_Loss:0.0443 ||Epoch_G_Loss:0.3906
# timer:  1.7294 sec.
# -------------
# epoch 180 || Epoch_D_Loss:0.0296 ||Epoch_G_Loss:0.4051
# timer:  1.7367 sec.
# -------------
# epoch 181 || Epoch_D_Loss:0.0407 ||Epoch_G_Loss:0.3735
# timer:  1.7378 sec.
# -------------
# epoch 182 || Epoch_D_Loss:0.0422 ||Epoch_G_Loss:0.4385
# timer:  1.7232 sec.
# -------------
# epoch 183 || Epoch_D_Loss:0.0450 ||Epoch_G_Loss:0.3454
# timer:  1.7225 sec.
# -------------
# epoch 184 || Epoch_D_Loss:0.0321 ||Epoch_G_Loss:0.3925
# timer:  1.7151 sec.
# -------------
# epoch 185 || Epoch_D_Loss:0.0391 ||Epoch_G_Loss:0.4071
# timer:  1.7475 sec.
# -------------
# epoch 186 || Epoch_D_Loss:0.0292 ||Epoch_G_Loss:0.4101
# timer:  1.7320 sec.
# -------------
# epoch 187 || Epoch_D_Loss:0.0457 ||Epoch_G_Loss:0.4429
# timer:  1.7285 sec.
# -------------
# epoch 188 || Epoch_D_Loss:0.0284 ||Epoch_G_Loss:0.3939
# timer:  1.7339 sec.
# -------------
# epoch 189 || Epoch_D_Loss:0.0364 ||Epoch_G_Loss:0.4066
# timer:  1.7447 sec.
# -------------
# epoch 190 || Epoch_D_Loss:0.0395 ||Epoch_G_Loss:0.4368
# timer:  1.7318 sec.
# -------------
# epoch 191 || Epoch_D_Loss:0.0372 ||Epoch_G_Loss:0.4132
# timer:  1.7414 sec.
# -------------
# epoch 192 || Epoch_D_Loss:0.0299 ||Epoch_G_Loss:0.4229
# timer:  1.7323 sec.
# -------------
# epoch 193 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.3955
# timer:  1.7386 sec.
# -------------
# epoch 194 || Epoch_D_Loss:0.0213 ||Epoch_G_Loss:0.4324
# timer:  1.7335 sec.
# -------------
# epoch 195 || Epoch_D_Loss:0.0373 ||Epoch_G_Loss:0.4483
# timer:  1.7343 sec.
# -------------
# epoch 196 || Epoch_D_Loss:0.0356 ||Epoch_G_Loss:0.3635
# timer:  1.7251 sec.
# -------------
# epoch 197 || Epoch_D_Loss:0.0369 ||Epoch_G_Loss:0.4616
# timer:  1.7243 sec.
# -------------
# epoch 198 || Epoch_D_Loss:0.0228 ||Epoch_G_Loss:0.4378
# timer:  1.7220 sec.
# -------------
# epoch 199 || Epoch_D_Loss:0.0290 ||Epoch_G_Loss:0.4419
# timer:  1.7365 sec.
# -------------
# epoch 200 || Epoch_D_Loss:0.0456 ||Epoch_G_Loss:0.4606
# timer:  1.7237 sec.
# -------------
# epoch 201 || Epoch_D_Loss:0.0212 ||Epoch_G_Loss:0.4212
# timer:  1.7340 sec.
# -------------
# epoch 202 || Epoch_D_Loss:0.0251 ||Epoch_G_Loss:0.4733
# timer:  1.7326 sec.
# -------------
# epoch 203 || Epoch_D_Loss:0.0476 ||Epoch_G_Loss:0.3530
# timer:  1.7466 sec.
# -------------
# epoch 204 || Epoch_D_Loss:0.0127 ||Epoch_G_Loss:0.5642
# timer:  1.7316 sec.
# -------------
# epoch 205 || Epoch_D_Loss:0.0560 ||Epoch_G_Loss:0.3664
# timer:  1.7388 sec.
# -------------
# epoch 206 || Epoch_D_Loss:0.0126 ||Epoch_G_Loss:0.4902
# timer:  1.7401 sec.
# -------------
# epoch 207 || Epoch_D_Loss:0.0300 ||Epoch_G_Loss:0.5259
# timer:  1.7399 sec.
# -------------
# epoch 208 || Epoch_D_Loss:0.0333 ||Epoch_G_Loss:0.4193
# timer:  1.7380 sec.
# -------------
# epoch 209 || Epoch_D_Loss:0.0324 ||Epoch_G_Loss:0.4851
# timer:  1.7454 sec.
# -------------
# epoch 210 || Epoch_D_Loss:0.0146 ||Epoch_G_Loss:0.4891
# timer:  1.7421 sec.
# -------------
# epoch 211 || Epoch_D_Loss:0.0287 ||Epoch_G_Loss:0.4848
# timer:  1.7391 sec.
# -------------
# epoch 212 || Epoch_D_Loss:0.0271 ||Epoch_G_Loss:0.5125
# timer:  1.7320 sec.
# -------------
# epoch 213 || Epoch_D_Loss:0.0360 ||Epoch_G_Loss:0.4589
# timer:  1.7380 sec.
# -------------
# epoch 214 || Epoch_D_Loss:0.0111 ||Epoch_G_Loss:0.5032
# timer:  1.7305 sec.
# -------------
# epoch 215 || Epoch_D_Loss:0.0418 ||Epoch_G_Loss:0.4399
# timer:  1.7228 sec.
# -------------
# epoch 216 || Epoch_D_Loss:0.0248 ||Epoch_G_Loss:0.5191
# timer:  1.7384 sec.
# -------------
# epoch 217 || Epoch_D_Loss:0.0298 ||Epoch_G_Loss:0.5233
# timer:  1.7401 sec.
# -------------
# epoch 218 || Epoch_D_Loss:0.0331 ||Epoch_G_Loss:0.4470
# timer:  1.7353 sec.
# -------------
# epoch 219 || Epoch_D_Loss:0.0282 ||Epoch_G_Loss:0.5189
# timer:  1.7395 sec.
# -------------
# epoch 220 || Epoch_D_Loss:0.0163 ||Epoch_G_Loss:0.4761
# timer:  1.7356 sec.
# -------------
# epoch 221 || Epoch_D_Loss:0.0124 ||Epoch_G_Loss:0.5825
# timer:  1.7294 sec.
# -------------
# epoch 222 || Epoch_D_Loss:0.0313 ||Epoch_G_Loss:0.4599
# timer:  1.7370 sec.
# -------------
# epoch 223 || Epoch_D_Loss:0.0342 ||Epoch_G_Loss:0.4764
# timer:  1.7412 sec.
# -------------
# epoch 224 || Epoch_D_Loss:0.0293 ||Epoch_G_Loss:0.4527
# timer:  1.7373 sec.
# -------------
# epoch 225 || Epoch_D_Loss:0.0123 ||Epoch_G_Loss:0.5138
# timer:  1.7317 sec.
# -------------
# epoch 226 || Epoch_D_Loss:0.0264 ||Epoch_G_Loss:0.5062
# timer:  1.7448 sec.
# -------------
# epoch 227 || Epoch_D_Loss:0.0217 ||Epoch_G_Loss:0.5475
# timer:  1.7430 sec.
# -------------
# epoch 228 || Epoch_D_Loss:0.0148 ||Epoch_G_Loss:0.5520
# timer:  1.7325 sec.
# -------------
# epoch 229 || Epoch_D_Loss:0.0306 ||Epoch_G_Loss:0.5017
# timer:  1.7388 sec.
# -------------
# epoch 230 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.5630
# timer:  1.7279 sec.
# -------------
# epoch 231 || Epoch_D_Loss:0.0403 ||Epoch_G_Loss:0.4932
# timer:  1.7209 sec.
# -------------
# epoch 232 || Epoch_D_Loss:0.0095 ||Epoch_G_Loss:0.5298
# timer:  1.7273 sec.
# -------------
# epoch 233 || Epoch_D_Loss:0.0137 ||Epoch_G_Loss:0.5774
# timer:  1.7387 sec.
# -------------
# epoch 234 || Epoch_D_Loss:0.0553 ||Epoch_G_Loss:0.4365
# timer:  1.7393 sec.
# -------------
# epoch 235 || Epoch_D_Loss:0.0136 ||Epoch_G_Loss:0.4420
# timer:  1.7260 sec.
# -------------
# epoch 236 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.5613
# timer:  1.7476 sec.
# -------------
# epoch 237 || Epoch_D_Loss:0.0327 ||Epoch_G_Loss:0.5797
# timer:  1.7398 sec.
# -------------
# epoch 238 || Epoch_D_Loss:0.0138 ||Epoch_G_Loss:0.5007
# timer:  1.7415 sec.
# -------------
# epoch 239 || Epoch_D_Loss:0.0358 ||Epoch_G_Loss:0.5636
# timer:  1.7457 sec.
# -------------
# epoch 240 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.5413
# timer:  1.7321 sec.
# -------------
# epoch 241 || Epoch_D_Loss:0.0119 ||Epoch_G_Loss:0.6092
# timer:  1.7351 sec.
# -------------
# epoch 242 || Epoch_D_Loss:0.0175 ||Epoch_G_Loss:0.5612
# timer:  1.7436 sec.
# -------------
# epoch 243 || Epoch_D_Loss:0.0585 ||Epoch_G_Loss:0.5268
# timer:  1.7512 sec.
# -------------
# epoch 244 || Epoch_D_Loss:0.0139 ||Epoch_G_Loss:0.4445
# timer:  1.7430 sec.
# -------------
# epoch 245 || Epoch_D_Loss:0.0103 ||Epoch_G_Loss:0.5438
# timer:  1.7393 sec.
# -------------
# epoch 246 || Epoch_D_Loss:0.0051 ||Epoch_G_Loss:0.6550
# timer:  1.7327 sec.
# -------------
# epoch 247 || Epoch_D_Loss:0.0364 ||Epoch_G_Loss:0.4820
# timer:  1.7208 sec.
# -------------
# epoch 248 || Epoch_D_Loss:0.0075 ||Epoch_G_Loss:0.5708
# timer:  1.7251 sec.
# -------------
# epoch 249 || Epoch_D_Loss:0.0304 ||Epoch_G_Loss:0.5934
# timer:  1.7375 sec.
# -------------
# epoch 250 || Epoch_D_Loss:0.0042 ||Epoch_G_Loss:0.6044
# timer:  1.7234 sec.
# -------------
# epoch 251 || Epoch_D_Loss:0.0484 ||Epoch_G_Loss:0.5496
# timer:  1.7344 sec.
# -------------
# epoch 252 || Epoch_D_Loss:0.0090 ||Epoch_G_Loss:0.5148
# timer:  1.7289 sec.
# -------------
# epoch 253 || Epoch_D_Loss:0.0135 ||Epoch_G_Loss:0.6219
# timer:  1.7468 sec.
# -------------
# epoch 254 || Epoch_D_Loss:0.0259 ||Epoch_G_Loss:0.5462
# timer:  1.7317 sec.
# -------------
# epoch 255 || Epoch_D_Loss:0.0118 ||Epoch_G_Loss:0.5553
# timer:  1.7389 sec.
# -------------
# epoch 256 || Epoch_D_Loss:0.0692 ||Epoch_G_Loss:0.5791
# timer:  1.7349 sec.
# -------------
# epoch 257 || Epoch_D_Loss:0.0115 ||Epoch_G_Loss:0.4304
# timer:  1.7421 sec.
# -------------
# epoch 258 || Epoch_D_Loss:0.0079 ||Epoch_G_Loss:0.5427
# timer:  1.7329 sec.
# -------------
# epoch 259 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.6088
# timer:  1.7248 sec.
# -------------
# epoch 260 || Epoch_D_Loss:0.0379 ||Epoch_G_Loss:0.5922
# timer:  1.7288 sec.
# -------------
# epoch 261 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.5237
# timer:  1.7286 sec.
# -------------
# epoch 262 || Epoch_D_Loss:0.0045 ||Epoch_G_Loss:0.6691
# timer:  1.7169 sec.
# -------------
# epoch 263 || Epoch_D_Loss:0.0488 ||Epoch_G_Loss:0.5045
# timer:  1.7200 sec.
# -------------
# epoch 264 || Epoch_D_Loss:0.0077 ||Epoch_G_Loss:0.5986
# timer:  1.7300 sec.
# -------------
# epoch 265 || Epoch_D_Loss:0.0243 ||Epoch_G_Loss:0.5517
# timer:  1.7336 sec.
# -------------
# epoch 266 || Epoch_D_Loss:0.0069 ||Epoch_G_Loss:0.6225
# timer:  1.7295 sec.
# -------------
# epoch 267 || Epoch_D_Loss:0.0312 ||Epoch_G_Loss:0.6092
# timer:  1.7431 sec.
# -------------
# epoch 268 || Epoch_D_Loss:0.0049 ||Epoch_G_Loss:0.6255
# timer:  1.7573 sec.
# -------------
# epoch 269 || Epoch_D_Loss:0.0257 ||Epoch_G_Loss:0.6135
# timer:  1.7244 sec.
# -------------
# epoch 270 || Epoch_D_Loss:0.0209 ||Epoch_G_Loss:0.5925
# timer:  1.7313 sec.
# -------------
# epoch 271 || Epoch_D_Loss:0.0182 ||Epoch_G_Loss:0.5469
# timer:  1.7296 sec.
# -------------
# epoch 272 || Epoch_D_Loss:0.0154 ||Epoch_G_Loss:0.6088
# timer:  1.7348 sec.
# -------------
# epoch 273 || Epoch_D_Loss:0.0035 ||Epoch_G_Loss:0.6854
# timer:  1.7176 sec.
# -------------
# epoch 274 || Epoch_D_Loss:0.0292 ||Epoch_G_Loss:0.5762
# timer:  1.7188 sec.
# -------------
# epoch 275 || Epoch_D_Loss:0.0190 ||Epoch_G_Loss:0.6871
# timer:  1.7188 sec.
# -------------
# epoch 276 || Epoch_D_Loss:0.0295 ||Epoch_G_Loss:0.4723
# timer:  1.7310 sec.
# -------------
# epoch 277 || Epoch_D_Loss:0.0060 ||Epoch_G_Loss:0.6105
# timer:  1.7418 sec.
# -------------
# epoch 278 || Epoch_D_Loss:0.0194 ||Epoch_G_Loss:0.6582
# timer:  1.7282 sec.
# -------------
# epoch 279 || Epoch_D_Loss:0.0073 ||Epoch_G_Loss:0.6710
# timer:  1.7228 sec.
# -------------
# epoch 280 || Epoch_D_Loss:0.0308 ||Epoch_G_Loss:0.6203
# timer:  1.7309 sec.
# -------------
# epoch 281 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.6075
# timer:  1.7260 sec.
# -------------
# epoch 282 || Epoch_D_Loss:0.0037 ||Epoch_G_Loss:0.6799
# timer:  1.7332 sec.
# -------------
# epoch 283 || Epoch_D_Loss:0.0176 ||Epoch_G_Loss:0.6968
# timer:  1.7224 sec.
# -------------
# epoch 284 || Epoch_D_Loss:0.0218 ||Epoch_G_Loss:0.5398
# timer:  1.7198 sec.
# -------------
# epoch 285 || Epoch_D_Loss:0.0036 ||Epoch_G_Loss:0.6422
# timer:  1.7301 sec.
# -------------
# epoch 286 || Epoch_D_Loss:0.0282 ||Epoch_G_Loss:0.7343
# timer:  1.7314 sec.
# -------------
# epoch 287 || Epoch_D_Loss:0.0280 ||Epoch_G_Loss:0.5076
# timer:  1.7146 sec.
# -------------
# epoch 288 || Epoch_D_Loss:0.0113 ||Epoch_G_Loss:0.6200
# timer:  1.7352 sec.
# -------------
# epoch 289 || Epoch_D_Loss:0.0040 ||Epoch_G_Loss:0.6724
# timer:  1.7251 sec.
# -------------
# epoch 290 || Epoch_D_Loss:0.0022 ||Epoch_G_Loss:0.7228
# timer:  1.7398 sec.
# -------------
# epoch 291 || Epoch_D_Loss:0.0407 ||Epoch_G_Loss:0.6346
# timer:  1.7306 sec.
# -------------
# epoch 292 || Epoch_D_Loss:0.0080 ||Epoch_G_Loss:0.5916
# timer:  1.7314 sec.
# -------------
# epoch 293 || Epoch_D_Loss:0.0270 ||Epoch_G_Loss:0.5732
# timer:  1.7335 sec.
# -------------
# epoch 294 || Epoch_D_Loss:0.0062 ||Epoch_G_Loss:0.5882
# timer:  1.7236 sec.
# -------------
# epoch 295 || Epoch_D_Loss:0.0038 ||Epoch_G_Loss:0.6742
# timer:  1.7400 sec.
# -------------
# epoch 296 || Epoch_D_Loss:0.0399 ||Epoch_G_Loss:0.7358
# timer:  1.7206 sec.
# -------------
# epoch 297 || Epoch_D_Loss:0.0202 ||Epoch_G_Loss:0.4493
# timer:  1.7167 sec.
# -------------
# epoch 298 || Epoch_D_Loss:0.0063 ||Epoch_G_Loss:0.5730
# timer:  1.7361 sec.
# -------------
# epoch 299 || Epoch_D_Loss:0.0030 ||Epoch_G_Loss:0.7134
# timer:  1.7243 sec.
# -------------
# epoch 300 || Epoch_D_Loss:0.0396 ||Epoch_G_Loss:0.5926
# timer:  1.7237 sec.
# 総イテレーション回数: 2101

# %%
'''訓練イテレーションごとの損失'''

plt.figure(figsize=(10,5))
plt.title("Generator and Discriminator Loss During Training")
plt.plot(raw_lossesG,label="G")
plt.plot(raw_lossesD,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
'''エポックごとの損失'''

plt.figure(figsize=(10,5))
plt.title("Epoch_Loss")
plt.plot(lossesG,label="G")
plt.plot(lossesD,label="D")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# 生成画像と訓練データを可視化する

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 入力の乱数生成
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)
fake_images = G_update(fixed_z.to(device))

# 訓練データ
batch_iterator = iter(train_dataloader)  # イテレータに変換
imgs = next(batch_iterator)  # 1番目の要素を取り出す


# 出力
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # 上段に訓練データを
    plt.subplot(2, 5, i+1)
    plt.imshow(imgs[i][0].cpu().detach().numpy(), 'gray')

    # 下段に生成データを表示する
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %%
def Anomaly_score(x, fake_img, D, Lambda=0.1):

    # テスト画像xと生成画像fake_imgのピクセルレベルの差の絶対値を求めて、ミニバッチごとに和を求める
    residual_loss = torch.abs(x-fake_img)
    residual_loss = residual_loss.view(residual_loss.size()[0], -1)
    residual_loss = torch.sum(residual_loss, dim=1)

    # テスト画像xと生成画像fake_imgを識別器Dに入力し、特徴量を取り出す
    _, x_feature = D(x)
    _, G_feature = D(fake_img)

    # テスト画像xと生成画像fake_imgの特徴量の差の絶対値を求めて、ミニバッチごとに和を求める
    discrimination_loss = torch.abs(x_feature-G_feature)
    
    discrimination_loss = torch.sum(discrimination_loss, dim=1)

    # ミニバッチごとに2種類の損失を足し算する
    loss_each = (1-Lambda)*residual_loss + Lambda*discrimination_loss

    # ミニバッチ全部の損失を求める
    total_loss = torch.sum(loss_each)

    return total_loss, loss_each, residual_loss

# %%
# テスト用のDataLoaderの作成


def make_test_datapath_list():
    """学習、検証の画像データとアノテーションデータへのファイルパスリストを作成する。 """

    train_img_list = list()  # 画像ファイルパスを格納

    for img_idx in range(20):
        img_path = "./data/test/img_7_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_8_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

        img_path = "./data/test/img_2_" + str(img_idx)+'.jpg'
        train_img_list.append(img_path)

    return train_img_list


# ファイルリストを作成
test_img_list = make_test_datapath_list()
print(test_img_list)

# Datasetを作成
mean = (0.5,)
std = (0.5,)
test_dataset = GAN_Img_Dataset(
    file_list=test_img_list, transform=ImageTransform(mean, std))

# DataLoaderを作成
batch_size = 60

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# ['./data/test/img_7_0.jpg', './data/test/img_8_0.jpg', './data/test/img_2_0.jpg', './data/test/img_7_1.jpg', './data/test/img_8_1.jpg', './data/test/img_2_1.jpg', './data/test/img_7_2.jpg', './data/test/img_8_2.jpg', './data/test/img_2_2.jpg', './data/test/img_7_3.jpg', './data/test/img_8_3.jpg', './data/test/img_2_3.jpg', './data/test/img_7_4.jpg', './data/test/img_8_4.jpg', './data/test/img_2_4.jpg', './data/test/img_7_5.jpg', './data/test/img_8_5.jpg', './data/test/img_2_5.jpg', './data/test/img_7_6.jpg', './data/test/img_8_6.jpg', './data/test/img_2_6.jpg', './data/test/img_7_7.jpg', './data/test/img_8_7.jpg', './data/test/img_2_7.jpg', './data/test/img_7_8.jpg', './data/test/img_8_8.jpg', './data/test/img_2_8.jpg', './data/test/img_7_9.jpg', './data/test/img_8_9.jpg', './data/test/img_2_9.jpg', './data/test/img_7_10.jpg', './data/test/img_8_10.jpg', './data/test/img_2_10.jpg', './data/test/img_7_11.jpg', './data/test/img_8_11.jpg', './data/test/img_2_11.jpg', './data/test/img_7_12.jpg', './data/test/img_8_12.jpg', './data/test/img_2_12.jpg', './data/test/img_7_13.jpg', './data/test/img_8_13.jpg', './data/test/img_2_13.jpg', './data/test/img_7_14.jpg', './data/test/img_8_14.jpg', './data/test/img_2_14.jpg', './data/test/img_7_15.jpg', './data/test/img_8_15.jpg', './data/test/img_2_15.jpg', './data/test/img_7_16.jpg', './data/test/img_8_16.jpg', './data/test/img_2_16.jpg', './data/test/img_7_17.jpg', './data/test/img_8_17.jpg', './data/test/img_2_17.jpg', './data/test/img_7_18.jpg', './data/test/img_8_18.jpg', './data/test/img_2_18.jpg', './data/test/img_7_19.jpg', './data/test/img_8_19.jpg', './data/test/img_2_19.jpg']

# %%
# テストデータの確認
batch_iterator = iter(test_dataloader)  # イテレータに変換
imgs = next(batch_iterator)
print(imgs.shape) 

# 1番目のミニバッチを取り出す

fig = plt.figure(figsize=(15, 6))
for i in range(0, 60):
    plt.subplot(12, 5, i+1)
    plt.imshow(imgs[i][0].cpu().detach().numpy(), 'gray')
# Out:
# torch.Size([60, 1, 64, 64])

# %%
# 異常検知したい画像
x = imgs
x = x.to(device)

# 異常検知したい画像を生成するための、初期乱数
z = torch.randn(60, 20).to(device)
z = z.view(z.size(0), z.size(1), 1, 1)

# 変数zを微分を求めることが可能なように、requires_gradをTrueに設定
z.requires_grad = True

# 変数zを更新できるように、zの最適化関数を求める
optimizerZ = torch.optim.Adam([z], lr=1e-3)


# zを求める
for epoch in range(5000+1):
    fake_img = G_update(z)
    loss, _, _ = Anomaly_score(x, fake_img, D_update, Lambda=0.1)

    optimizerZ.zero_grad()
    loss.backward()
    optimizerZ.step()

    if epoch % 1000 == 0:
        print(f'epoch {epoch+1} || loss_total:{loss.item():.0f} ')
# Out:
# epoch 1 || loss_total:74042
# epoch 1001 || loss_total:52237
# epoch 2001 || loss_total:45005
# epoch 3001 || loss_total:41882
# epoch 4001 || loss_total:40354
# epoch 5001 || loss_total:39577

# %%
# 画像を生成
G_update.eval()
fake_img = G_update(z)

# 損失を求める
loss, loss_each, residual_loss_each = Anomaly_score(
    x, fake_img, D_update, Lambda=0.1)

# 損失の計算。トータルの損失
loss_each = loss_each.cpu().detach().numpy()
print("total loss：", np.round(loss_each, 0))

# 画像を可視化

print('テストデータ')
fig = plt.figure(figsize=(15, 6))
for i in range(0, 20):
    # 上段にテストデータを
    plt.subplot(2, 20, i+1)
    plt.imshow(imgs[i][0].cpu().detach().numpy(), 'gray')
plt.show()

print('生成データ')
fig = plt.figure(figsize=(15, 6))
for i in range(0, 20):
    # 下段に生成データを表示する
    plt.subplot(2, 20, i+1)
    plt.imshow(fake_img[i][0].cpu().detach().numpy(), 'gray')
plt.show()
# Out:
# total loss： [ 688.  835.  996.  595.  778.  809.  209.  910.  712.  961.  842.  978.
#   172.  573. 1028.  208.  454.  888.  576.  549.  947.  240.  903. 1153.
#   195.  828. 1098.  261.  532.  931.  466.  547.  693.  242.  705.  636.
#   386.  801. 1016.  404.  877.  880.  225.  616.  827.  317.  653.  921.
#   268.  631. 1073.  238.  511.  758.  246.  528. 1155.  272.  621. 1211.]
# テストデータ
# 生成データ

# %%
'''テストデータのlossをデータフレーム化'''

test_df = pd.DataFrame({'files': test_img_list})
test_df['label'] = test_df['files'].apply(lambda x: x.split('_')[1])
test_df['loss'] = loss_each
test_df.head()
# Out:
#                      files label        loss
# 0  ./data/test/img_7_0.jpg     7  687.942383
# 1  ./data/test/img_8_0.jpg     8  835.126099
# 2  ./data/test/img_2_0.jpg     2  995.842407
# 3  ./data/test/img_7_1.jpg     7  594.597900
# 4  ./data/test/img_8_1.jpg     8  777.968872

# %%
'''テストデータのlossを可視化'''

sns.set_style('whitegrid')
sns.set_palette('Set1')
sns.histplot(data=test_df, x='loss', hue='label', alpha=0.5, bins=50)
plt.show()
